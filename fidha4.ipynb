# %%
num=int(input("enter a no:"))
if num%7==0:
  print("divisible")
else:
  print("not divisible")
# Out:
# enter a no:14
# divisible

# %%
char=str(input("enter a character:"))
vowels="a,e,i,o,u,A,E,I,O,U"
if char in vowels:
    print("vowels")
else:
    print("not")
# Out:
# enter a character:q
# not

# %%
num1=int(input("enter first string:"))
num2=int(input("enetr second string:"))
if num1==num2:
    print("equal")
else:
    print("not")
# Out:
# enter first string:3
# enetr second string:4
# not

# %%
pr=int(input("enter the purchase amount:"))
if pr>5000:
    print("eligible for discount")
else:
    print("not")
# Out:
# enter the purchase amount:2000
# not

# %%
num=int(input("enter a num :"))
if num>=10 and num<=100:
    print ("it lies between 10 and 100")
else:
    print ("not")
# Out:
# enter a num :2
# not

# %%
age=int(input("enter the age")) 
if age>=18:
    print("eligible") 
else: 
    print("not")
# Out:
# enter the age24
# eligible

# %%
att=float(input("enter the percentage:"))
if att>=75:
    print("eligible")
else:
    print("not eligible")
# Out:
# enter the percentage:80
# eligible

# %%
num=int(input("enetr a no:"))
if num>=100 and num<=999:
    print ("three digit no")
else:
    print("not")
# Out:
# enetr a no:1000
# not

# %%
ch=str(input("enter a alphabet:"))
lowercase="a,b,c,d,d,f,f,g"
if ch in lowercase:
    print ("lowercase")
else:
    print ("uppercase")
# Out:
# enter a alphabet:A
# uppercase
