# %%
mark=[10,20,30,40]
print(mark[0])
# Out:
# 10

# %%
a=[0,1,2,3,4]
a.append(5)
print(a)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
numbers=(10,20,30,40,50)
print(numbers[2])
# Out:
# 30

# %%
no={10,10,20,30,20}
print(no)
# Out:
# {10, 20, 30}

# %%
student={"name":"fidha","age":22}
print(student['name'])
# Out:
# fidha

# %%
name="fathima"
print(name[0],name[6])
# Out:
# f a
